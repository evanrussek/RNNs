# %%
# %run train_sim_and_human_optimal.py
# Out:
# Training on simulated data
# Training on human data
# Human epoch: 0
# Human epoch: 1
# batch num38 sim test loss: 7.3069662432516775 human test loss 7.575049015783494
# Human epoch: 2
# Human epoch: 3
# batch num14 sim test loss: 5.760954533853838 human test loss 5.7753436027034635
# Human epoch: 4
# batch num52 sim test loss: 5.279877355021815 human test loss 5.291503844722625
# Human epoch: 5
# Human epoch: 6
# batch num28 sim test loss: 4.992528592386553 human test loss 5.010208468283376
# Human epoch: 7
# Human epoch: 8
# batch num4 sim test loss: 4.874579706499653 human test loss 4.903170616396012
# Human epoch: 9
# batch num42 sim test loss: 4.828451141234367 human test loss 4.859540208693473
# Human epoch: 10
# Human epoch: 11
# batch num18 sim test loss: 4.822053132518645 human test loss 4.8536802338015645
# Human epoch: 12
# batch num56 sim test loss: 4.822042811301447 human test loss 4.850179018512849
# Human epoch: 13
# Human epoch: 14
# ...

# %%
prop_pretrain = np.linspace(0,1,5);

# %%
prop_pretrain
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])
