# %%
import os
import numpy as np
import pickle

from main_as_fun import main_as_fun

is_array_job=False

if is_array_job:
    job_idx = int(os.environ["SLURM_ARRAY_TASK_ID"]) - 1
else:
    job_idx = 3

    
## Make folder to save best params
best_param_folder = '/home/erussek/projects/RNNs/best_hyper_params_sequential'

# Read in best hyper params...
best_param_dict = pickle.load(open(os.path.join(best_param_folder, 'best_hyper_params.pkl'), 'rb'))

# types of models...
model_names = ['LSTM', 'GRU', 'Transformer']
part_names = ["Simulated_Only","Simulated_Only_Pred_Human", "Human_Only", "Simulated_and_Human"]

# %%
# best_param_dict
# Out:
# {'fix_only_Simulated_Only_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 409632,
#   'best_hum_num': 0,
#   'min_loss': 4.742460861802101},
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 115232,
#   'best_hum_num': 0,
#   'min_loss': 5.7704736441373825},
#  'fix_only_Simulated_Only_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.715113304555416},
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 454432,
#   'best_hum_num': 0,
#   'min_loss': 5.797056466341019},
#  'fix_only_Simulated_Only_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 409632,
#   'best_hum_num': 0,
#   'min_loss': 4.731983549892902},
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 128,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 6432,
#   'best_hum_num': 0,
#   'min_loss': 5.766371458768845},
#  'fix_only_Human_Only_LSTM_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 128,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 697600,
#   'min_loss': 5.6712212562561035},
#  'fix_only_Human_Only_GRU_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 876800,
#   'min_loss': 5.662978440523148},
#  'fix_only_Human_Only_Transformer_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 64,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 25600,
#   'min_loss': 5.678844213485718},
#  'fix_only_Simulated_and_Human_LSTM_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.633329764008522},
#  'fix_only_Simulated_and_Human_GRU_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 70400,
#   'min_loss': 5.615413203835487},
#  'fix_only_Simulated_and_Human_Transformer_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 64,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.612446799874306},
#  'fix_and_choice_Simulated_Only_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.684612475335598},
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 83232,
#   'best_hum_num': 0,
#   'min_loss': 5.714393138885498},
#  'fix_and_choice_Simulated_Only_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.682588942348957},
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 454432,
#   'best_hum_num': 0,
#   'min_loss': 5.765377163887024},
#  'fix_and_choice_Simulated_Only_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.708600759506226},
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 64,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 6432,
#   'best_hum_num': 0,
#   'min_loss': 5.71734856069088},
#  'fix_and_choice_Human_Only_LSTM_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 473600,
#   'min_loss': 5.617699071764946},
#  'fix_and_choice_Human_Only_GRU_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 384000,
#   'min_loss': 5.631696581840515},
#  'fix_and_choice_Human_Only_Transformer_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 12800,
#   'min_loss': 5.648593693971634},
#  'fix_and_choice_Simulated_and_Human_LSTM_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 57600,
#   'min_loss': 5.577784210443497},
#  'fix_and_choice_Simulated_and_Human_GRU_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.567006841301918},
#  'fix_and_choice_Simulated_and_Human_Transformer_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.581438764929771},
#  'fix_only_Simulated_Only_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 64,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.728043235838413},
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 467232,
#   'best_hum_num': 0,
#   'min_loss': 5.8274807035923},
#  'fix_only_Simulated_Only_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.709532164037228},
#  'fix_only_Simulated_Only_Pred_Human_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.781591936945915},
#  'fix_only_Simulated_Only_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.711358688771725},
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 83232,
#   'best_hum_num': 0,
#   'min_loss': 5.778577595949173},
#  'fix_only_Human_Only_LSTM_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 160000,
#   'min_loss': 5.654189884662628},
#  'fix_only_Human_Only_GRU_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 115200,
#   'min_loss': 5.649518236517906},
#  'fix_only_Human_Only_Transformer_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 204800,
#   'min_loss': 5.672599211335182},
#  'fix_only_Simulated_and_Human_LSTM_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.635955557227135},
#  'fix_only_Simulated_and_Human_GRU_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.599663287401199},
#  'fix_only_Simulated_and_Human_Transformer_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 249600,
#   'min_loss': 5.590992704033852},
#  'fix_and_choice_Simulated_Only_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.6911446377635},
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 128,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.788312554359436},
#  'fix_and_choice_Simulated_Only_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 403232,
#   'best_hum_num': 0,
#   'min_loss': 4.68400888890028},
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.747027724981308},
#  'fix_and_choice_Simulated_Only_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 249632,
#   'best_hum_num': 0,
#   'min_loss': 4.684794843196869},
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 179232,
#   'best_hum_num': 0,
#   'min_loss': 5.729503631591797},
#  'fix_and_choice_Human_Only_LSTM_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 64,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 172800,
#   'min_loss': 5.615233480930328},
#  'fix_and_choice_Human_Only_GRU_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 32,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 115200,
#   'min_loss': 5.618001714348793},
#  'fix_and_choice_Human_Only_Transformer_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 64,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 70400,
#   'min_loss': 5.636945128440857},
#  'fix_and_choice_Simulated_and_Human_LSTM_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 64,
#   'sim_lr': 0.001,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 70400,
#   'min_loss': 5.5787596851587296},
#  'fix_and_choice_Simulated_and_Human_GRU_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0.001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.560820892453194},
#  'fix_and_choice_Simulated_and_Human_Transformer_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 32,
#   'sim_lr': 0.001,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 25600,
#   'min_loss': 5.541592851281166}}

# %%
job_model_names = []
job_hidden_sizes = []
job_sim_lrs = []
job_human_lrs = []
job_attention_heads = []
job_layers = []
job_runs = []
job_n_sim_seqs = []
job_n_human_seqs = []
job_train_names = []
job_full_names = []
job_tsps = []

# for simulated only -- find both the params that maximize simulated data performance 
# and also the params that maximize human performance

n_runs = 50
for run in range(n_runs):
    for fu in fix_unit_types:
        for model_name in model_names:
            for tsp in train_seq_parts:
                for part_name in part_names:
                    full_name = "{}_{}_{}_{}".format(tsp, part_name, model_name, fu)
                    job_full_names.append(full_name + '_run_{}'.format(run))
                    mbp = best_param_dict[full_name]
                    
                    job_runs.append(run)
                    job_tsps.append(tsp)
                    job_model_names.append(mbp['model_name'])
                    job_hidden_sizes.append(mbp['d_model'])
                    job_sim_lrs.append(mbp['sim_lr'])
                    job_human_lrs.append(mbp['human_lr'])
                    job_attention_heads.append(mbp['n_head'])
                    job_layers.append(mbp['n_layers'])
                    
                    if part_name == 'Simulated_Only':
                        job_n_sim_seqs.append(1e6)
                    else:

                        job_n_sim_seqs.append(mbp['best_sim_num'])
                        
                    job_n_human_seqs.append(mbp['best_hum_num'])
                    job_train_names.append(part_name)
                    
                    

run_idx = job_runs[job_idx]
model_name = job_model_names[job_idx]
d_model = job_hidden_sizes[job_idx]
sim_lr = job_sim_lrs[job_idx]
human_lr = job_human_lrs[job_idx]
n_head = job_attention_heads[job_idx]
n_layers = job_layers[job_idx]
n_simulation_sequences_train = job_n_sim_seqs[job_idx]
n_human_sequences_train = job_n_human_seqs[job_idx]
train_name = job_train_names[job_idx]

save_file_name = job_full_names[job_idx]

main_as_fun(
    run_idx = job_runs[job_idx],
    model_name = job_model_names[job_idx],
    d_model = job_hidden_sizes[job_idx],
    sim_lr = job_sim_lrs[job_idx],
    human_lr = job_human_lrs[job_idx],
    n_head = job_attention_heads[job_idx],
    n_layers = job_layers[job_idx],
    train_seq_part = job_tsps[job_idx],
    n_simulation_sequences_train = job_n_sim_seqs[job_idx],
    n_human_sequences_train = job_n_human_seqs[job_idx],
    dropout = .1,
    on_cluster = True,
    save_folder_name = 'Sequential_Best_Param_Results',
    save_file_name = save_file_name)
# Out:
# {'model_name': 'LSTM', 'train_seq_part': 'fix_and_choice', 'n_simulation_sequences_train': 1000000.0, 'n_human_sequences_train': 0, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 256, 'n_layers': 0, 'n_head': 0, 'sim_lr': 0.001, 'human_lr': 0, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 0, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Sequential_Best_Param_Results', 'save_file_name': 'fix_and_choice_Simulated_Only_LSTM_ID_run_0', 'fix_unit': 'ID'}
# <class 'float'>
# Loading Data
# /home/erussek/.conda/envs/pDL/lib/python3.8/site-packages/torch/nn/modules/rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# cpu
# Training the model
# Training on simulated data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1201203/1354747126.py in <module>
#      58 save_file_name = job_full_names[job_idx]
#      59
# ---> 60 main_as_fun(
#      61     run_idx = job_runs[job_idx],
#      62     model_name = job_model_names[job_idx],
#
# ~/projects/RNNs/main_as_fun.py in main_as_fun(model_name, train_seq_part, n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, n_sequences_final_performance, d_model, n_layers, n_head, sim_lr, human_lr, batch_size, dropout, run_idx, on_cluster, test_batch_increment_sim, test_batch_increment_human, save_folder_name, fix_unit, save_file_name)
#     117
#     118     print("Training the model")
# --> 119     simulation_loss_results, human_loss_results, train_sequence_number,human_sequence_number, simulation_sequence_number, model = train_on_simulation_then_human_with_intermediate_tests(model,train_data_sim, train_data_human,val_data_sim,val_data_human,criterion,device,batch_size,n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, gen_data_func, sim_lr = sim_lr, human_lr = human_lr, test_batch_increment_sim=test_batch_increment_sim, test_batch_increment_human=test_batch_increment_human)
#     120
#     121     # save results of this
#
# ~/projects/RNNs/train_and_test_funs.py in train_on_simulation_then_human_with_intermediate_tests(model, train_data_sim, train_data_human, test_data_sim, test_data_human, criterion, device, batch_size, n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, gen_batch_data, sim_lr, human_lr, test_batch_increment_sim, test_batch_increment_human)
#     124
#     125         # update model, running a single batch on simulation data
# --> 126         model = run_batch_update_model(model,train_data_sim, gen_batch_data, batch_size,batch_idx, optimizer, criterion, device, use_human_data=False)
#     127
#     128         # if we're on a test increment, test the model and record the results
#
# ~/projects/RNNs/train_and_test_funs.py in run_batch_update_model(model, train_data, gen_batch_data, batch_size, batch_idx, optimizer, criterion, device, use_human_data)
#     211     optimizer.zero_grad() # step 3
#     212
# --> 213     loss.backward() # step 4
#     214
#     215     optimizer.step() # step 5
#
# ~/.conda/envs/pDL/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/.conda/envs/pDL/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
# 2400
len(job_model_names)
# Out:
# 2400

# %%
# %run ID_Best_Hyperparams_Sequential.py

# %%
job_full_names
# Out:
# ['fix_only_Simulated_Only_LSTM_ID_run_0',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_0',
#  'fix_only_Human_Only_LSTM_ID_run_0',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_0',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_0',
#  'fix_and_choice_Human_Only_LSTM_ID_run_0',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_0',
#  'fix_only_Simulated_Only_GRU_ID_run_0',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_0',
#  'fix_only_Human_Only_GRU_ID_run_0',
#  'fix_only_Simulated_and_Human_GRU_ID_run_0',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_0',
#  'fix_and_choice_Human_Only_GRU_ID_run_0',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_0',
#  'fix_only_Simulated_Only_Transformer_ID_run_0',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_0',
#  'fix_only_Human_Only_Transformer_ID_run_0',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_0',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_0',
#  'fix_and_choice_Human_Only_Transformer_ID_run_0',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_0',
#  'fix_only_Simulated_Only_LSTM_all_run_0',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_0',
#  'fix_only_Human_Only_LSTM_all_run_0',
#  'fix_only_Simulated_and_Human_LSTM_all_run_0',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_0',
#  'fix_and_choice_Human_Only_LSTM_all_run_0',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_0',
#  'fix_only_Simulated_Only_GRU_all_run_0',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_0',
#  'fix_only_Human_Only_GRU_all_run_0',
#  'fix_only_Simulated_and_Human_GRU_all_run_0',
#  'fix_and_choice_Simulated_Only_GRU_all_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_0',
#  'fix_and_choice_Human_Only_GRU_all_run_0',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_0',
#  'fix_only_Simulated_Only_Transformer_all_run_0',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_0',
#  'fix_only_Human_Only_Transformer_all_run_0',
#  'fix_only_Simulated_and_Human_Transformer_all_run_0',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_0',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_0',
#  'fix_and_choice_Human_Only_Transformer_all_run_0',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_0',
#  'fix_only_Simulated_Only_LSTM_ID_run_1',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_1',
#  'fix_only_Human_Only_LSTM_ID_run_1',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_1',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_1',
#  'fix_and_choice_Human_Only_LSTM_ID_run_1',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_1',
#  'fix_only_Simulated_Only_GRU_ID_run_1',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_1',
#  'fix_only_Human_Only_GRU_ID_run_1',
#  'fix_only_Simulated_and_Human_GRU_ID_run_1',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_1',
#  'fix_and_choice_Human_Only_GRU_ID_run_1',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_1',
#  'fix_only_Simulated_Only_Transformer_ID_run_1',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_1',
#  'fix_only_Human_Only_Transformer_ID_run_1',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_1',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_1',
#  'fix_and_choice_Human_Only_Transformer_ID_run_1',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_1',
#  'fix_only_Simulated_Only_LSTM_all_run_1',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_1',
#  'fix_only_Human_Only_LSTM_all_run_1',
#  'fix_only_Simulated_and_Human_LSTM_all_run_1',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_1',
#  'fix_and_choice_Human_Only_LSTM_all_run_1',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_1',
#  'fix_only_Simulated_Only_GRU_all_run_1',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_1',
#  'fix_only_Human_Only_GRU_all_run_1',
#  'fix_only_Simulated_and_Human_GRU_all_run_1',
#  'fix_and_choice_Simulated_Only_GRU_all_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_1',
#  'fix_and_choice_Human_Only_GRU_all_run_1',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_1',
#  'fix_only_Simulated_Only_Transformer_all_run_1',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_1',
#  'fix_only_Human_Only_Transformer_all_run_1',
#  'fix_only_Simulated_and_Human_Transformer_all_run_1',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_1',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_1',
#  'fix_and_choice_Human_Only_Transformer_all_run_1',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_1',
#  'fix_only_Simulated_Only_LSTM_ID_run_2',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_2',
#  'fix_only_Human_Only_LSTM_ID_run_2',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_2',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_2',
#  'fix_and_choice_Human_Only_LSTM_ID_run_2',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_2',
#  'fix_only_Simulated_Only_GRU_ID_run_2',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_2',
#  'fix_only_Human_Only_GRU_ID_run_2',
#  'fix_only_Simulated_and_Human_GRU_ID_run_2',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_2',
#  'fix_and_choice_Human_Only_GRU_ID_run_2',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_2',
#  'fix_only_Simulated_Only_Transformer_ID_run_2',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_2',
#  'fix_only_Human_Only_Transformer_ID_run_2',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_2',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_2',
#  'fix_and_choice_Human_Only_Transformer_ID_run_2',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_2',
#  'fix_only_Simulated_Only_LSTM_all_run_2',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_2',
#  'fix_only_Human_Only_LSTM_all_run_2',
#  'fix_only_Simulated_and_Human_LSTM_all_run_2',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_2',
#  'fix_and_choice_Human_Only_LSTM_all_run_2',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_2',
#  'fix_only_Simulated_Only_GRU_all_run_2',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_2',
#  'fix_only_Human_Only_GRU_all_run_2',
#  'fix_only_Simulated_and_Human_GRU_all_run_2',
#  'fix_and_choice_Simulated_Only_GRU_all_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_2',
#  'fix_and_choice_Human_Only_GRU_all_run_2',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_2',
#  'fix_only_Simulated_Only_Transformer_all_run_2',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_2',
#  'fix_only_Human_Only_Transformer_all_run_2',
#  'fix_only_Simulated_and_Human_Transformer_all_run_2',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_2',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_2',
#  'fix_and_choice_Human_Only_Transformer_all_run_2',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_2',
#  'fix_only_Simulated_Only_LSTM_ID_run_3',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_3',
#  'fix_only_Human_Only_LSTM_ID_run_3',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_3',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_3',
#  'fix_and_choice_Human_Only_LSTM_ID_run_3',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_3',
#  'fix_only_Simulated_Only_GRU_ID_run_3',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_3',
#  'fix_only_Human_Only_GRU_ID_run_3',
#  'fix_only_Simulated_and_Human_GRU_ID_run_3',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_3',
#  'fix_and_choice_Human_Only_GRU_ID_run_3',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_3',
#  'fix_only_Simulated_Only_Transformer_ID_run_3',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_3',
#  'fix_only_Human_Only_Transformer_ID_run_3',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_3',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_3',
#  'fix_and_choice_Human_Only_Transformer_ID_run_3',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_3',
#  'fix_only_Simulated_Only_LSTM_all_run_3',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_3',
#  'fix_only_Human_Only_LSTM_all_run_3',
#  'fix_only_Simulated_and_Human_LSTM_all_run_3',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_3',
#  'fix_and_choice_Human_Only_LSTM_all_run_3',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_3',
#  'fix_only_Simulated_Only_GRU_all_run_3',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_3',
#  'fix_only_Human_Only_GRU_all_run_3',
#  'fix_only_Simulated_and_Human_GRU_all_run_3',
#  'fix_and_choice_Simulated_Only_GRU_all_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_3',
#  'fix_and_choice_Human_Only_GRU_all_run_3',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_3',
#  'fix_only_Simulated_Only_Transformer_all_run_3',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_3',
#  'fix_only_Human_Only_Transformer_all_run_3',
#  'fix_only_Simulated_and_Human_Transformer_all_run_3',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_3',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_3',
#  'fix_and_choice_Human_Only_Transformer_all_run_3',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_3',
#  'fix_only_Simulated_Only_LSTM_ID_run_4',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_4',
#  'fix_only_Human_Only_LSTM_ID_run_4',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_4',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_4',
#  'fix_and_choice_Human_Only_LSTM_ID_run_4',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_4',
#  'fix_only_Simulated_Only_GRU_ID_run_4',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_4',
#  'fix_only_Human_Only_GRU_ID_run_4',
#  'fix_only_Simulated_and_Human_GRU_ID_run_4',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_4',
#  'fix_and_choice_Human_Only_GRU_ID_run_4',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_4',
#  'fix_only_Simulated_Only_Transformer_ID_run_4',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_4',
#  'fix_only_Human_Only_Transformer_ID_run_4',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_4',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_4',
#  'fix_and_choice_Human_Only_Transformer_ID_run_4',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_4',
#  'fix_only_Simulated_Only_LSTM_all_run_4',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_4',
#  'fix_only_Human_Only_LSTM_all_run_4',
#  'fix_only_Simulated_and_Human_LSTM_all_run_4',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_4',
#  'fix_and_choice_Human_Only_LSTM_all_run_4',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_4',
#  'fix_only_Simulated_Only_GRU_all_run_4',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_4',
#  'fix_only_Human_Only_GRU_all_run_4',
#  'fix_only_Simulated_and_Human_GRU_all_run_4',
#  'fix_and_choice_Simulated_Only_GRU_all_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_4',
#  'fix_and_choice_Human_Only_GRU_all_run_4',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_4',
#  'fix_only_Simulated_Only_Transformer_all_run_4',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_4',
#  'fix_only_Human_Only_Transformer_all_run_4',
#  'fix_only_Simulated_and_Human_Transformer_all_run_4',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_4',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_4',
#  'fix_and_choice_Human_Only_Transformer_all_run_4',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_4',
#  'fix_only_Simulated_Only_LSTM_ID_run_5',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_5',
#  'fix_only_Human_Only_LSTM_ID_run_5',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_5',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_5',
#  'fix_and_choice_Human_Only_LSTM_ID_run_5',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_5',
#  'fix_only_Simulated_Only_GRU_ID_run_5',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_5',
#  'fix_only_Human_Only_GRU_ID_run_5',
#  'fix_only_Simulated_and_Human_GRU_ID_run_5',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_5',
#  'fix_and_choice_Human_Only_GRU_ID_run_5',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_5',
#  'fix_only_Simulated_Only_Transformer_ID_run_5',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_5',
#  'fix_only_Human_Only_Transformer_ID_run_5',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_5',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_5',
#  'fix_and_choice_Human_Only_Transformer_ID_run_5',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_5',
#  'fix_only_Simulated_Only_LSTM_all_run_5',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_5',
#  'fix_only_Human_Only_LSTM_all_run_5',
#  'fix_only_Simulated_and_Human_LSTM_all_run_5',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_5',
#  'fix_and_choice_Human_Only_LSTM_all_run_5',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_5',
#  'fix_only_Simulated_Only_GRU_all_run_5',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_5',
#  'fix_only_Human_Only_GRU_all_run_5',
#  'fix_only_Simulated_and_Human_GRU_all_run_5',
#  'fix_and_choice_Simulated_Only_GRU_all_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_5',
#  'fix_and_choice_Human_Only_GRU_all_run_5',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_5',
#  'fix_only_Simulated_Only_Transformer_all_run_5',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_5',
#  'fix_only_Human_Only_Transformer_all_run_5',
#  'fix_only_Simulated_and_Human_Transformer_all_run_5',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_5',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_5',
#  'fix_and_choice_Human_Only_Transformer_all_run_5',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_5',
#  'fix_only_Simulated_Only_LSTM_ID_run_6',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_6',
#  'fix_only_Human_Only_LSTM_ID_run_6',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_6',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_6',
#  'fix_and_choice_Human_Only_LSTM_ID_run_6',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_6',
#  'fix_only_Simulated_Only_GRU_ID_run_6',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_6',
#  'fix_only_Human_Only_GRU_ID_run_6',
#  'fix_only_Simulated_and_Human_GRU_ID_run_6',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_6',
#  'fix_and_choice_Human_Only_GRU_ID_run_6',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_6',
#  'fix_only_Simulated_Only_Transformer_ID_run_6',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_6',
#  'fix_only_Human_Only_Transformer_ID_run_6',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_6',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_6',
#  'fix_and_choice_Human_Only_Transformer_ID_run_6',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_6',
#  'fix_only_Simulated_Only_LSTM_all_run_6',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_6',
#  'fix_only_Human_Only_LSTM_all_run_6',
#  'fix_only_Simulated_and_Human_LSTM_all_run_6',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_6',
#  'fix_and_choice_Human_Only_LSTM_all_run_6',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_6',
#  'fix_only_Simulated_Only_GRU_all_run_6',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_6',
#  'fix_only_Human_Only_GRU_all_run_6',
#  'fix_only_Simulated_and_Human_GRU_all_run_6',
#  'fix_and_choice_Simulated_Only_GRU_all_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_6',
#  'fix_and_choice_Human_Only_GRU_all_run_6',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_6',
#  'fix_only_Simulated_Only_Transformer_all_run_6',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_6',
#  'fix_only_Human_Only_Transformer_all_run_6',
#  'fix_only_Simulated_and_Human_Transformer_all_run_6',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_6',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_6',
#  'fix_and_choice_Human_Only_Transformer_all_run_6',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_6',
#  'fix_only_Simulated_Only_LSTM_ID_run_7',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_7',
#  'fix_only_Human_Only_LSTM_ID_run_7',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_7',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_7',
#  'fix_and_choice_Human_Only_LSTM_ID_run_7',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_7',
#  'fix_only_Simulated_Only_GRU_ID_run_7',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_7',
#  'fix_only_Human_Only_GRU_ID_run_7',
#  'fix_only_Simulated_and_Human_GRU_ID_run_7',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_7',
#  'fix_and_choice_Human_Only_GRU_ID_run_7',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_7',
#  'fix_only_Simulated_Only_Transformer_ID_run_7',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_7',
#  'fix_only_Human_Only_Transformer_ID_run_7',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_7',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_7',
#  'fix_and_choice_Human_Only_Transformer_ID_run_7',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_7',
#  'fix_only_Simulated_Only_LSTM_all_run_7',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_7',
#  'fix_only_Human_Only_LSTM_all_run_7',
#  'fix_only_Simulated_and_Human_LSTM_all_run_7',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_7',
#  'fix_and_choice_Human_Only_LSTM_all_run_7',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_7',
#  'fix_only_Simulated_Only_GRU_all_run_7',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_7',
#  'fix_only_Human_Only_GRU_all_run_7',
#  'fix_only_Simulated_and_Human_GRU_all_run_7',
#  'fix_and_choice_Simulated_Only_GRU_all_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_7',
#  'fix_and_choice_Human_Only_GRU_all_run_7',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_7',
#  'fix_only_Simulated_Only_Transformer_all_run_7',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_7',
#  'fix_only_Human_Only_Transformer_all_run_7',
#  'fix_only_Simulated_and_Human_Transformer_all_run_7',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_7',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_7',
#  'fix_and_choice_Human_Only_Transformer_all_run_7',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_7',
#  'fix_only_Simulated_Only_LSTM_ID_run_8',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_8',
#  'fix_only_Human_Only_LSTM_ID_run_8',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_8',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_8',
#  'fix_and_choice_Human_Only_LSTM_ID_run_8',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_8',
#  'fix_only_Simulated_Only_GRU_ID_run_8',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_8',
#  'fix_only_Human_Only_GRU_ID_run_8',
#  'fix_only_Simulated_and_Human_GRU_ID_run_8',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_8',
#  'fix_and_choice_Human_Only_GRU_ID_run_8',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_8',
#  'fix_only_Simulated_Only_Transformer_ID_run_8',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_8',
#  'fix_only_Human_Only_Transformer_ID_run_8',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_8',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_8',
#  'fix_and_choice_Human_Only_Transformer_ID_run_8',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_8',
#  'fix_only_Simulated_Only_LSTM_all_run_8',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_8',
#  'fix_only_Human_Only_LSTM_all_run_8',
#  'fix_only_Simulated_and_Human_LSTM_all_run_8',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_8',
#  'fix_and_choice_Human_Only_LSTM_all_run_8',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_8',
#  'fix_only_Simulated_Only_GRU_all_run_8',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_8',
#  'fix_only_Human_Only_GRU_all_run_8',
#  'fix_only_Simulated_and_Human_GRU_all_run_8',
#  'fix_and_choice_Simulated_Only_GRU_all_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_8',
#  'fix_and_choice_Human_Only_GRU_all_run_8',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_8',
#  'fix_only_Simulated_Only_Transformer_all_run_8',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_8',
#  'fix_only_Human_Only_Transformer_all_run_8',
#  'fix_only_Simulated_and_Human_Transformer_all_run_8',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_8',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_8',
#  'fix_and_choice_Human_Only_Transformer_all_run_8',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_8',
#  'fix_only_Simulated_Only_LSTM_ID_run_9',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_9',
#  'fix_only_Human_Only_LSTM_ID_run_9',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_9',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_9',
#  'fix_and_choice_Human_Only_LSTM_ID_run_9',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_9',
#  'fix_only_Simulated_Only_GRU_ID_run_9',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_9',
#  'fix_only_Human_Only_GRU_ID_run_9',
#  'fix_only_Simulated_and_Human_GRU_ID_run_9',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_9',
#  'fix_and_choice_Human_Only_GRU_ID_run_9',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_9',
#  'fix_only_Simulated_Only_Transformer_ID_run_9',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_9',
#  'fix_only_Human_Only_Transformer_ID_run_9',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_9',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_9',
#  'fix_and_choice_Human_Only_Transformer_ID_run_9',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_9',
#  'fix_only_Simulated_Only_LSTM_all_run_9',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_9',
#  'fix_only_Human_Only_LSTM_all_run_9',
#  'fix_only_Simulated_and_Human_LSTM_all_run_9',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_9',
#  'fix_and_choice_Human_Only_LSTM_all_run_9',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_9',
#  'fix_only_Simulated_Only_GRU_all_run_9',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_9',
#  'fix_only_Human_Only_GRU_all_run_9',
#  'fix_only_Simulated_and_Human_GRU_all_run_9',
#  'fix_and_choice_Simulated_Only_GRU_all_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_9',
#  'fix_and_choice_Human_Only_GRU_all_run_9',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_9',
#  'fix_only_Simulated_Only_Transformer_all_run_9',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_9',
#  'fix_only_Human_Only_Transformer_all_run_9',
#  'fix_only_Simulated_and_Human_Transformer_all_run_9',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_9',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_9',
#  'fix_and_choice_Human_Only_Transformer_all_run_9',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_9',
#  'fix_only_Simulated_Only_LSTM_ID_run_10',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_10',
#  'fix_only_Human_Only_LSTM_ID_run_10',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_10',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_10',
#  'fix_and_choice_Human_Only_LSTM_ID_run_10',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_10',
#  'fix_only_Simulated_Only_GRU_ID_run_10',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_10',
#  'fix_only_Human_Only_GRU_ID_run_10',
#  'fix_only_Simulated_and_Human_GRU_ID_run_10',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_10',
#  'fix_and_choice_Human_Only_GRU_ID_run_10',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_10',
#  'fix_only_Simulated_Only_Transformer_ID_run_10',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_10',
#  'fix_only_Human_Only_Transformer_ID_run_10',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_10',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_10',
#  'fix_and_choice_Human_Only_Transformer_ID_run_10',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_10',
#  'fix_only_Simulated_Only_LSTM_all_run_10',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_10',
#  'fix_only_Human_Only_LSTM_all_run_10',
#  'fix_only_Simulated_and_Human_LSTM_all_run_10',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_10',
#  'fix_and_choice_Human_Only_LSTM_all_run_10',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_10',
#  'fix_only_Simulated_Only_GRU_all_run_10',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_10',
#  'fix_only_Human_Only_GRU_all_run_10',
#  'fix_only_Simulated_and_Human_GRU_all_run_10',
#  'fix_and_choice_Simulated_Only_GRU_all_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_10',
#  'fix_and_choice_Human_Only_GRU_all_run_10',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_10',
#  'fix_only_Simulated_Only_Transformer_all_run_10',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_10',
#  'fix_only_Human_Only_Transformer_all_run_10',
#  'fix_only_Simulated_and_Human_Transformer_all_run_10',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_10',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_10',
#  'fix_and_choice_Human_Only_Transformer_all_run_10',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_10',
#  'fix_only_Simulated_Only_LSTM_ID_run_11',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_11',
#  'fix_only_Human_Only_LSTM_ID_run_11',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_11',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_11',
#  'fix_and_choice_Human_Only_LSTM_ID_run_11',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_11',
#  'fix_only_Simulated_Only_GRU_ID_run_11',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_11',
#  'fix_only_Human_Only_GRU_ID_run_11',
#  'fix_only_Simulated_and_Human_GRU_ID_run_11',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_11',
#  'fix_and_choice_Human_Only_GRU_ID_run_11',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_11',
#  'fix_only_Simulated_Only_Transformer_ID_run_11',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_11',
#  'fix_only_Human_Only_Transformer_ID_run_11',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_11',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_11',
#  'fix_and_choice_Human_Only_Transformer_ID_run_11',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_11',
#  'fix_only_Simulated_Only_LSTM_all_run_11',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_11',
#  'fix_only_Human_Only_LSTM_all_run_11',
#  'fix_only_Simulated_and_Human_LSTM_all_run_11',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_11',
#  'fix_and_choice_Human_Only_LSTM_all_run_11',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_11',
#  'fix_only_Simulated_Only_GRU_all_run_11',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_11',
#  'fix_only_Human_Only_GRU_all_run_11',
#  'fix_only_Simulated_and_Human_GRU_all_run_11',
#  'fix_and_choice_Simulated_Only_GRU_all_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_11',
#  'fix_and_choice_Human_Only_GRU_all_run_11',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_11',
#  'fix_only_Simulated_Only_Transformer_all_run_11',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_11',
#  'fix_only_Human_Only_Transformer_all_run_11',
#  'fix_only_Simulated_and_Human_Transformer_all_run_11',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_11',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_11',
#  'fix_and_choice_Human_Only_Transformer_all_run_11',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_11',
#  'fix_only_Simulated_Only_LSTM_ID_run_12',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_12',
#  'fix_only_Human_Only_LSTM_ID_run_12',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_12',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_12',
#  'fix_and_choice_Human_Only_LSTM_ID_run_12',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_12',
#  'fix_only_Simulated_Only_GRU_ID_run_12',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_12',
#  'fix_only_Human_Only_GRU_ID_run_12',
#  'fix_only_Simulated_and_Human_GRU_ID_run_12',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_12',
#  'fix_and_choice_Human_Only_GRU_ID_run_12',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_12',
#  'fix_only_Simulated_Only_Transformer_ID_run_12',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_12',
#  'fix_only_Human_Only_Transformer_ID_run_12',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_12',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_12',
#  'fix_and_choice_Human_Only_Transformer_ID_run_12',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_12',
#  'fix_only_Simulated_Only_LSTM_all_run_12',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_12',
#  'fix_only_Human_Only_LSTM_all_run_12',
#  'fix_only_Simulated_and_Human_LSTM_all_run_12',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_12',
#  'fix_and_choice_Human_Only_LSTM_all_run_12',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_12',
#  'fix_only_Simulated_Only_GRU_all_run_12',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_12',
#  'fix_only_Human_Only_GRU_all_run_12',
#  'fix_only_Simulated_and_Human_GRU_all_run_12',
#  'fix_and_choice_Simulated_Only_GRU_all_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_12',
#  'fix_and_choice_Human_Only_GRU_all_run_12',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_12',
#  'fix_only_Simulated_Only_Transformer_all_run_12',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_12',
#  'fix_only_Human_Only_Transformer_all_run_12',
#  'fix_only_Simulated_and_Human_Transformer_all_run_12',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_12',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_12',
#  'fix_and_choice_Human_Only_Transformer_all_run_12',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_12',
#  'fix_only_Simulated_Only_LSTM_ID_run_13',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_13',
#  'fix_only_Human_Only_LSTM_ID_run_13',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_13',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_13',
#  'fix_and_choice_Human_Only_LSTM_ID_run_13',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_13',
#  'fix_only_Simulated_Only_GRU_ID_run_13',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_13',
#  'fix_only_Human_Only_GRU_ID_run_13',
#  'fix_only_Simulated_and_Human_GRU_ID_run_13',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_13',
#  'fix_and_choice_Human_Only_GRU_ID_run_13',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_13',
#  'fix_only_Simulated_Only_Transformer_ID_run_13',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_13',
#  'fix_only_Human_Only_Transformer_ID_run_13',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_13',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_13',
#  'fix_and_choice_Human_Only_Transformer_ID_run_13',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_13',
#  'fix_only_Simulated_Only_LSTM_all_run_13',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_13',
#  'fix_only_Human_Only_LSTM_all_run_13',
#  'fix_only_Simulated_and_Human_LSTM_all_run_13',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_13',
#  'fix_and_choice_Human_Only_LSTM_all_run_13',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_13',
#  'fix_only_Simulated_Only_GRU_all_run_13',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_13',
#  'fix_only_Human_Only_GRU_all_run_13',
#  'fix_only_Simulated_and_Human_GRU_all_run_13',
#  'fix_and_choice_Simulated_Only_GRU_all_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_13',
#  'fix_and_choice_Human_Only_GRU_all_run_13',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_13',
#  'fix_only_Simulated_Only_Transformer_all_run_13',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_13',
#  'fix_only_Human_Only_Transformer_all_run_13',
#  'fix_only_Simulated_and_Human_Transformer_all_run_13',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_13',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_13',
#  'fix_and_choice_Human_Only_Transformer_all_run_13',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_13',
#  'fix_only_Simulated_Only_LSTM_ID_run_14',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_14',
#  'fix_only_Human_Only_LSTM_ID_run_14',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_14',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_14',
#  'fix_and_choice_Human_Only_LSTM_ID_run_14',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_14',
#  'fix_only_Simulated_Only_GRU_ID_run_14',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_14',
#  'fix_only_Human_Only_GRU_ID_run_14',
#  'fix_only_Simulated_and_Human_GRU_ID_run_14',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_14',
#  'fix_and_choice_Human_Only_GRU_ID_run_14',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_14',
#  'fix_only_Simulated_Only_Transformer_ID_run_14',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_14',
#  'fix_only_Human_Only_Transformer_ID_run_14',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_14',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_14',
#  'fix_and_choice_Human_Only_Transformer_ID_run_14',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_14',
#  'fix_only_Simulated_Only_LSTM_all_run_14',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_14',
#  'fix_only_Human_Only_LSTM_all_run_14',
#  'fix_only_Simulated_and_Human_LSTM_all_run_14',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_14',
#  'fix_and_choice_Human_Only_LSTM_all_run_14',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_14',
#  'fix_only_Simulated_Only_GRU_all_run_14',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_14',
#  'fix_only_Human_Only_GRU_all_run_14',
#  'fix_only_Simulated_and_Human_GRU_all_run_14',
#  'fix_and_choice_Simulated_Only_GRU_all_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_14',
#  'fix_and_choice_Human_Only_GRU_all_run_14',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_14',
#  'fix_only_Simulated_Only_Transformer_all_run_14',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_14',
#  'fix_only_Human_Only_Transformer_all_run_14',
#  'fix_only_Simulated_and_Human_Transformer_all_run_14',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_14',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_14',
#  'fix_and_choice_Human_Only_Transformer_all_run_14',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_14',
#  'fix_only_Simulated_Only_LSTM_ID_run_15',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_15',
#  'fix_only_Human_Only_LSTM_ID_run_15',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_15',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_15',
#  'fix_and_choice_Human_Only_LSTM_ID_run_15',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_15',
#  'fix_only_Simulated_Only_GRU_ID_run_15',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_15',
#  'fix_only_Human_Only_GRU_ID_run_15',
#  'fix_only_Simulated_and_Human_GRU_ID_run_15',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_15',
#  'fix_and_choice_Human_Only_GRU_ID_run_15',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_15',
#  'fix_only_Simulated_Only_Transformer_ID_run_15',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_15',
#  'fix_only_Human_Only_Transformer_ID_run_15',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_15',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_15',
#  'fix_and_choice_Human_Only_Transformer_ID_run_15',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_15',
#  'fix_only_Simulated_Only_LSTM_all_run_15',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_15',
#  'fix_only_Human_Only_LSTM_all_run_15',
#  'fix_only_Simulated_and_Human_LSTM_all_run_15',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_15',
#  'fix_and_choice_Human_Only_LSTM_all_run_15',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_15',
#  'fix_only_Simulated_Only_GRU_all_run_15',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_15',
#  'fix_only_Human_Only_GRU_all_run_15',
#  'fix_only_Simulated_and_Human_GRU_all_run_15',
#  'fix_and_choice_Simulated_Only_GRU_all_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_15',
#  'fix_and_choice_Human_Only_GRU_all_run_15',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_15',
#  'fix_only_Simulated_Only_Transformer_all_run_15',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_15',
#  'fix_only_Human_Only_Transformer_all_run_15',
#  'fix_only_Simulated_and_Human_Transformer_all_run_15',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_15',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_15',
#  'fix_and_choice_Human_Only_Transformer_all_run_15',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_15',
#  'fix_only_Simulated_Only_LSTM_ID_run_16',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_16',
#  'fix_only_Human_Only_LSTM_ID_run_16',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_16',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_16',
#  'fix_and_choice_Human_Only_LSTM_ID_run_16',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_16',
#  'fix_only_Simulated_Only_GRU_ID_run_16',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_16',
#  'fix_only_Human_Only_GRU_ID_run_16',
#  'fix_only_Simulated_and_Human_GRU_ID_run_16',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_16',
#  'fix_and_choice_Human_Only_GRU_ID_run_16',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_16',
#  'fix_only_Simulated_Only_Transformer_ID_run_16',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_16',
#  'fix_only_Human_Only_Transformer_ID_run_16',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_16',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_16',
#  'fix_and_choice_Human_Only_Transformer_ID_run_16',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_16',
#  'fix_only_Simulated_Only_LSTM_all_run_16',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_16',
#  'fix_only_Human_Only_LSTM_all_run_16',
#  'fix_only_Simulated_and_Human_LSTM_all_run_16',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_16',
#  'fix_and_choice_Human_Only_LSTM_all_run_16',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_16',
#  'fix_only_Simulated_Only_GRU_all_run_16',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_16',
#  'fix_only_Human_Only_GRU_all_run_16',
#  'fix_only_Simulated_and_Human_GRU_all_run_16',
#  'fix_and_choice_Simulated_Only_GRU_all_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_16',
#  'fix_and_choice_Human_Only_GRU_all_run_16',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_16',
#  'fix_only_Simulated_Only_Transformer_all_run_16',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_16',
#  'fix_only_Human_Only_Transformer_all_run_16',
#  'fix_only_Simulated_and_Human_Transformer_all_run_16',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_16',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_16',
#  'fix_and_choice_Human_Only_Transformer_all_run_16',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_16',
#  'fix_only_Simulated_Only_LSTM_ID_run_17',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_17',
#  'fix_only_Human_Only_LSTM_ID_run_17',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_17',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_17',
#  'fix_and_choice_Human_Only_LSTM_ID_run_17',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_17',
#  'fix_only_Simulated_Only_GRU_ID_run_17',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_17',
#  'fix_only_Human_Only_GRU_ID_run_17',
#  'fix_only_Simulated_and_Human_GRU_ID_run_17',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_17',
#  'fix_and_choice_Human_Only_GRU_ID_run_17',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_17',
#  'fix_only_Simulated_Only_Transformer_ID_run_17',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_17',
#  'fix_only_Human_Only_Transformer_ID_run_17',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_17',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_17',
#  'fix_and_choice_Human_Only_Transformer_ID_run_17',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_17',
#  'fix_only_Simulated_Only_LSTM_all_run_17',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_17',
#  'fix_only_Human_Only_LSTM_all_run_17',
#  'fix_only_Simulated_and_Human_LSTM_all_run_17',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_17',
#  'fix_and_choice_Human_Only_LSTM_all_run_17',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_17',
#  'fix_only_Simulated_Only_GRU_all_run_17',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_17',
#  'fix_only_Human_Only_GRU_all_run_17',
#  'fix_only_Simulated_and_Human_GRU_all_run_17',
#  'fix_and_choice_Simulated_Only_GRU_all_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_17',
#  'fix_and_choice_Human_Only_GRU_all_run_17',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_17',
#  'fix_only_Simulated_Only_Transformer_all_run_17',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_17',
#  'fix_only_Human_Only_Transformer_all_run_17',
#  'fix_only_Simulated_and_Human_Transformer_all_run_17',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_17',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_17',
#  'fix_and_choice_Human_Only_Transformer_all_run_17',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_17',
#  'fix_only_Simulated_Only_LSTM_ID_run_18',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_18',
#  'fix_only_Human_Only_LSTM_ID_run_18',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_18',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_18',
#  'fix_and_choice_Human_Only_LSTM_ID_run_18',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_18',
#  'fix_only_Simulated_Only_GRU_ID_run_18',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_18',
#  'fix_only_Human_Only_GRU_ID_run_18',
#  'fix_only_Simulated_and_Human_GRU_ID_run_18',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_18',
#  'fix_and_choice_Human_Only_GRU_ID_run_18',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_18',
#  'fix_only_Simulated_Only_Transformer_ID_run_18',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_18',
#  'fix_only_Human_Only_Transformer_ID_run_18',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_18',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_18',
#  'fix_and_choice_Human_Only_Transformer_ID_run_18',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_18',
#  'fix_only_Simulated_Only_LSTM_all_run_18',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_18',
#  'fix_only_Human_Only_LSTM_all_run_18',
#  'fix_only_Simulated_and_Human_LSTM_all_run_18',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_18',
#  'fix_and_choice_Human_Only_LSTM_all_run_18',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_18',
#  'fix_only_Simulated_Only_GRU_all_run_18',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_18',
#  'fix_only_Human_Only_GRU_all_run_18',
#  'fix_only_Simulated_and_Human_GRU_all_run_18',
#  'fix_and_choice_Simulated_Only_GRU_all_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_18',
#  'fix_and_choice_Human_Only_GRU_all_run_18',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_18',
#  'fix_only_Simulated_Only_Transformer_all_run_18',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_18',
#  'fix_only_Human_Only_Transformer_all_run_18',
#  'fix_only_Simulated_and_Human_Transformer_all_run_18',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_18',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_18',
#  'fix_and_choice_Human_Only_Transformer_all_run_18',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_18',
#  'fix_only_Simulated_Only_LSTM_ID_run_19',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_19',
#  'fix_only_Human_Only_LSTM_ID_run_19',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_19',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_19',
#  'fix_and_choice_Human_Only_LSTM_ID_run_19',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_19',
#  'fix_only_Simulated_Only_GRU_ID_run_19',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_19',
#  'fix_only_Human_Only_GRU_ID_run_19',
#  'fix_only_Simulated_and_Human_GRU_ID_run_19',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_19',
#  'fix_and_choice_Human_Only_GRU_ID_run_19',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_19',
#  'fix_only_Simulated_Only_Transformer_ID_run_19',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_19',
#  'fix_only_Human_Only_Transformer_ID_run_19',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_19',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_19',
#  'fix_and_choice_Human_Only_Transformer_ID_run_19',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_19',
#  'fix_only_Simulated_Only_LSTM_all_run_19',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_19',
#  'fix_only_Human_Only_LSTM_all_run_19',
#  'fix_only_Simulated_and_Human_LSTM_all_run_19',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_19',
#  'fix_and_choice_Human_Only_LSTM_all_run_19',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_19',
#  'fix_only_Simulated_Only_GRU_all_run_19',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_19',
#  'fix_only_Human_Only_GRU_all_run_19',
#  'fix_only_Simulated_and_Human_GRU_all_run_19',
#  'fix_and_choice_Simulated_Only_GRU_all_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_19',
#  'fix_and_choice_Human_Only_GRU_all_run_19',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_19',
#  'fix_only_Simulated_Only_Transformer_all_run_19',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all_run_19',
#  'fix_only_Human_Only_Transformer_all_run_19',
#  'fix_only_Simulated_and_Human_Transformer_all_run_19',
#  'fix_and_choice_Simulated_Only_Transformer_all_run_19',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all_run_19',
#  'fix_and_choice_Human_Only_Transformer_all_run_19',
#  'fix_and_choice_Simulated_and_Human_Transformer_all_run_19',
#  'fix_only_Simulated_Only_LSTM_ID_run_20',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID_run_20',
#  'fix_only_Human_Only_LSTM_ID_run_20',
#  'fix_only_Simulated_and_Human_LSTM_ID_run_20',
#  'fix_and_choice_Simulated_Only_LSTM_ID_run_20',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID_run_20',
#  'fix_and_choice_Human_Only_LSTM_ID_run_20',
#  'fix_and_choice_Simulated_and_Human_LSTM_ID_run_20',
#  'fix_only_Simulated_Only_GRU_ID_run_20',
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID_run_20',
#  'fix_only_Human_Only_GRU_ID_run_20',
#  'fix_only_Simulated_and_Human_GRU_ID_run_20',
#  'fix_and_choice_Simulated_Only_GRU_ID_run_20',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID_run_20',
#  'fix_and_choice_Human_Only_GRU_ID_run_20',
#  'fix_and_choice_Simulated_and_Human_GRU_ID_run_20',
#  'fix_only_Simulated_Only_Transformer_ID_run_20',
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID_run_20',
#  'fix_only_Human_Only_Transformer_ID_run_20',
#  'fix_only_Simulated_and_Human_Transformer_ID_run_20',
#  'fix_and_choice_Simulated_Only_Transformer_ID_run_20',
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID_run_20',
#  'fix_and_choice_Human_Only_Transformer_ID_run_20',
#  'fix_and_choice_Simulated_and_Human_Transformer_ID_run_20',
#  'fix_only_Simulated_Only_LSTM_all_run_20',
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all_run_20',
#  'fix_only_Human_Only_LSTM_all_run_20',
#  'fix_only_Simulated_and_Human_LSTM_all_run_20',
#  'fix_and_choice_Simulated_Only_LSTM_all_run_20',
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all_run_20',
#  'fix_and_choice_Human_Only_LSTM_all_run_20',
#  'fix_and_choice_Simulated_and_Human_LSTM_all_run_20',
#  'fix_only_Simulated_Only_GRU_all_run_20',
#  'fix_only_Simulated_Only_Pred_Human_GRU_all_run_20',
#  'fix_only_Human_Only_GRU_all_run_20',
#  'fix_only_Simulated_and_Human_GRU_all_run_20',
#  'fix_and_choice_Simulated_Only_GRU_all_run_20',
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all_run_20',
#  'fix_and_choice_Human_Only_GRU_all_run_20',
#  'fix_and_choice_Simulated_and_Human_GRU_all_run_20',
#  ...]
