# %%
import os
import numpy as np
import pickle


## Make folder to save best params
best_param_folder = '/home/erussek/projects/RNNs/best_hyper_params_sequential'

# Read in best hyper params...
best_param_dict = pickle.load(open(os.path.join(best_param_folder, 'best_hyper_params.pkl'), 'rb'))

# types of models...
model_names = ['LSTM', 'GRU', 'Transformer']
# part_names = ["Simulated_Only","Simulated_Only_Pred_Human", "Human_Only", "Simulated_and_Human"]
part_names = ["Simulated_and_Human"]
fix_unit_types = ['ID', 'all']
# train_seq_parts = ['fix_only', 'fix_and_choice']
train_seq_parts = ['fix_only', 'fix_and_choice']

# %%
# %run ID_Best_Hyperparams_Sequential.py

# %%
#%run Train_at_Best_Params_Sequential.py
# Out:
# 12
# {'model_name': 'LSTM', 'train_seq_part': 'fix_and_choice', 'n_simulation_sequences_train': 0, 'n_human_sequences_train': 697600, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 512, 'n_layers': 0, 'n_head': 0, 'sim_lr': 0, 'human_lr': 0.0001, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 1, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Sequential_Best_Param_Results', 'save_file_name': 'fix_and_choice_Human_Only_LSTM_ID_run_1', 'fix_unit': 'ID'}
# <class 'numpy.int64'>
# Loading Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.conda/envs/pDL/lib/python3.8/site-packages/IPython/utils/py3compat.py in execfile(fname, glob, loc, compiler)
#     167         compiler = compiler or compile
# --> 168         exec(compiler(f.read(), fname, 'exec'), glob, loc)
#     169
#
# ~/projects/RNNs/Train_at_Best_Params_Sequential.py in <module>
#     114
# --> 115     main_as_fun(
#     116         run_idx = job_runs[job_idx],
#
# ~/projects/RNNs/main_as_fun.py in main_as_fun(model_name, train_seq_part, n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, n_sequences_final_performance, d_model, n_layers, n_head, sim_lr, human_lr, batch_size, dropout, run_idx, on_cluster, test_batch_increment_sim, test_batch_increment_human, save_folder_name, fix_unit, save_file_name)
#      80     print("Loading Data")
# ---> 81     train_data_sim, val_data_sim, test_data_sim, train_data_human, val_data_human, test_data_human = load_data(sim_data_path, human_data_path,this_seed=run_idx,split_human_data=True)
#      82
#
# ~/projects/RNNs/load_data_funs.py in load_data(sim_data_path, human_data_path, split_human_data, this_seed)
#      22
# ---> 23     a = [json.load(open(train_files[i])) for i in range(15)]
#      24     train_trials = [item for sublist in a for item in sublist]
#
# ~/projects/RNNs/load_data_funs.py in <listcomp>(.0)
#      22
# ---> 23     a = [json.load(open(train_files[i])) for i in range(15)]
#      24     train_trials = [item for sublist in a for item in sublist]
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
# 1200 / 4

# %%
len(job_model_names)
# Out:
# 1200

# %%
best_param_dict
# Out:
# {'fix_only_Simulated_Only_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 409632,
#   'best_hum_num': 0,
#   'min_loss': 4.742460861802101},
#  'fix_only_Simulated_Only_Pred_Human_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 70432,
#   'best_hum_num': 0,
#   'min_loss': 5.770775303244591},
#  'fix_only_Simulated_Only_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.738745957612991},
#  'fix_only_Simulated_Only_Pred_Human_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.8116573840379715},
#  'fix_only_Simulated_Only_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.739600710570812},
#  'fix_only_Simulated_Only_Pred_Human_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 268832,
#   'best_hum_num': 0,
#   'min_loss': 5.796075418591499},
#  'fix_only_Human_Only_LSTM_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 710400,
#   'min_loss': 5.679871052503586},
#  'fix_only_Human_Only_GRU_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 249600,
#   'min_loss': 5.694063872098923},
#  'fix_only_Human_Only_Transformer_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 25600,
#   'min_loss': 5.699427574872971},
#  'fix_only_Simulated_and_Human_LSTM_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 262400,
#   'min_loss': 5.634346500039101},
#  'fix_only_Simulated_and_Human_GRU_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 384000,
#   'min_loss': 5.628347173333168},
#  'fix_only_Simulated_and_Human_Transformer_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 6400,
#   'min_loss': 5.7334839552640915},
#  'fix_and_choice_Simulated_Only_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.684612475335598},
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 83232,
#   'best_hum_num': 0,
#   'min_loss': 5.714393138885498},
#  'fix_and_choice_Simulated_Only_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.683872692286968},
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 345632,
#   'best_hum_num': 0,
#   'min_loss': 5.7668381333351135},
#  'fix_and_choice_Simulated_Only_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 249632,
#   'best_hum_num': 0,
#   'min_loss': 4.721712090075016},
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_ID': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 128032,
#   'best_hum_num': 0,
#   'min_loss': 5.768084347248077},
#  'fix_and_choice_Human_Only_LSTM_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 518400,
#   'min_loss': 5.631916165351868},
#  'fix_and_choice_Human_Only_GRU_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 204800,
#   'min_loss': 5.662347316741943},
#  'fix_and_choice_Human_Only_Transformer_ID': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 12800,
#   'min_loss': 5.648593693971634},
#  'fix_and_choice_Simulated_and_Human_LSTM_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 563200,
#   'min_loss': 5.599060237407684},
#  'fix_and_choice_Simulated_and_Human_GRU_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 160000,
#   'min_loss': 5.570679396390915},
#  'fix_and_choice_Simulated_and_Human_Transformer_ID': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'ID',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 889600,
#   'min_loss': 5.72492353618145},
#  'fix_only_Simulated_Only_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 441632,
#   'best_hum_num': 0,
#   'min_loss': 4.733791962265968},
#  'fix_only_Simulated_Only_Pred_Human_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 467232,
#   'best_hum_num': 0,
#   'min_loss': 5.8274807035923},
#  'fix_only_Simulated_Only_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 403232,
#   'best_hum_num': 0,
#   'min_loss': 4.710553579032421},
#  'fix_only_Simulated_Only_Pred_Human_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.781591936945915},
#  'fix_only_Simulated_Only_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.711358688771725},
#  'fix_only_Simulated_Only_Pred_Human_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 83232,
#   'best_hum_num': 0,
#   'min_loss': 5.778577595949173},
#  'fix_only_Human_Only_LSTM_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 160000,
#   'min_loss': 5.7238673865795135},
#  'fix_only_Human_Only_GRU_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 160000,
#   'min_loss': 5.701403930783272},
#  'fix_only_Human_Only_Transformer_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 12800,
#   'min_loss': 5.675447195768356},
#  'fix_only_Simulated_and_Human_LSTM_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 307200,
#   'min_loss': 5.639190301299095},
#  'fix_only_Simulated_and_Human_GRU_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 249600,
#   'min_loss': 5.60748752951622},
#  'fix_only_Simulated_and_Human_Transformer_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_only',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 262400,
#   'min_loss': 5.645684361457825},
#  'fix_and_choice_Simulated_Only_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 499232,
#   'best_hum_num': 0,
#   'min_loss': 4.6911446377635},
#  'fix_and_choice_Simulated_Only_Pred_Human_LSTM_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 460832,
#   'best_hum_num': 0,
#   'min_loss': 5.790769562125206},
#  'fix_and_choice_Simulated_Only_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 403232,
#   'best_hum_num': 0,
#   'min_loss': 4.68400888890028},
#  'fix_and_choice_Simulated_Only_Pred_Human_GRU_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 364832,
#   'best_hum_num': 0,
#   'min_loss': 5.747027724981308},
#  'fix_and_choice_Simulated_Only_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.0001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 409632,
#   'best_hum_num': 0,
#   'min_loss': 4.690986789762974},
#  'fix_and_choice_Simulated_Only_Pred_Human_Transformer_all': {'part_name': 'Simulated_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 0,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 179232,
#   'best_hum_num': 0,
#   'min_loss': 5.729503631591797},
#  'fix_and_choice_Human_Only_LSTM_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 204800,
#   'min_loss': 5.683777883648872},
#  'fix_and_choice_Human_Only_GRU_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.0001,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 0,
#   'best_hum_num': 294400,
#   'min_loss': 5.653202846646309},
#  'fix_and_choice_Human_Only_Transformer_all': {'part_name': 'Human_Only',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0,
#   'human_lr': 0.001,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 0,
#   'best_hum_num': 57600,
#   'min_loss': 5.647315710783005},
#  'fix_and_choice_Simulated_and_Human_LSTM_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'LSTM',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 384000,
#   'min_loss': 5.590654358267784},
#  'fix_and_choice_Simulated_and_Human_GRU_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'GRU',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 0,
#   'n_layers': 0,
#   'best_sim_num': 294432,
#   'best_hum_num': 249600,
#   'min_loss': 5.587373644113541},
#  'fix_and_choice_Simulated_and_Human_Transformer_all': {'part_name': 'Simulated_and_Human',
#   'train_seq_part': 'fix_and_choice',
#   'fu': 'all',
#   'model_name': 'Transformer',
#   'd_model': 256,
#   'sim_lr': 0.001,
#   'human_lr': 1e-05,
#   'n_head': 4,
#   'n_layers': 2,
#   'best_sim_num': 294432,
#   'best_hum_num': 153600,
#   'min_loss': 5.624826073646545}}

# %%
# %run Search_Hyper_Params_Sequential.py
# Out:
# {'model_name': 'LSTM', 'train_seq_part': 'fix_and_choice', 'n_simulation_sequences_train': 0, 'n_human_sequences_train': 1000000.0, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 512, 'n_layers': 0, 'n_head': 0, 'sim_lr': 0, 'human_lr': 0.0001, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 0, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Hyper_Param_Search_Sequential', 'save_file_name': 'Human_Only_fix_and_choice_ID_run_0_model_name_LSTM_d_model_512_sim_lr_0_human_lr_0.0001_n_head_0_n_layers_0', 'fix_unit': 'ID'}
# <class 'int'>
# Loading Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/projects/RNNs/Search_Hyper_Params_Sequential.py in <module>
#     237 save_file_name = '{}_{}_{}_run_{}_model_name_{}_d_model_{}_sim_lr_{}_human_lr_{}_n_head_{}_n_layers_{}'.format(part_name,train_seq_part, fu, run_idx, model_name, d_model, sim_lr, human_lr, n_head, n_layers)
#     238
# --> 239 main_as_fun(
#     240     run_idx = job_runs[job_idx],
#     241     model_name = job_model_names[job_idx],
#
# ~/projects/RNNs/main_as_fun.py in main_as_fun(model_name, train_seq_part, n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, n_sequences_final_performance, d_model, n_layers, n_head, sim_lr, human_lr, batch_size, dropout, run_idx, on_cluster, test_batch_increment_sim, test_batch_increment_human, save_folder_name, fix_unit, save_file_name)
#      79     #####################
#      80     print("Loading Data")
# ---> 81     train_data_sim, val_data_sim, test_data_sim, train_data_human, val_data_human, test_data_human = load_data(sim_data_path, human_data_path,this_seed=run_idx,split_human_data=True)
#      82
#      83     ##########################
#
# ~/projects/RNNs/load_data_funs.py in load_data(sim_data_path, human_data_path, split_human_data, this_seed)
#      26     train_data_sim = train_trials[:int(1.8e6)]
#      27
# ---> 28     test_trials = json.load(open(test_files[0]))
#      29     test_data_sim = test_trials[:int(1e5)]
#      30     del test_trials
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
len(job_runs)
# Out:
# 720

# %%
# %run Train_at_Best_Params_Sequential.py
# Out:
# 12
# {'model_name': 'LSTM', 'train_seq_part': 'fix_and_choice', 'n_simulation_sequences_train': 294432, 'n_human_sequences_train': 563200, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 256, 'n_layers': 0, 'n_head': 0, 'sim_lr': 0.001, 'human_lr': 1e-05, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 6, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Sequential_Best_Param_Results', 'save_file_name': 'fix_and_choice_Simulated_and_Human_LSTM_ID_run_6', 'fix_unit': 'ID'}
# <class 'numpy.int64'>
# Loading Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.conda/envs/pDL/lib/python3.8/site-packages/IPython/utils/py3compat.py in execfile(fname, glob, loc, compiler)
#     167         compiler = compiler or compile
# --> 168         exec(compiler(f.read(), fname, 'exec'), glob, loc)
#     169
#
# ~/projects/RNNs/Train_at_Best_Params_Sequential.py in <module>
#     114
# --> 115     main_as_fun(
#     116         run_idx = job_runs[job_idx],
#
# ~/projects/RNNs/main_as_fun.py in main_as_fun(model_name, train_seq_part, n_simulation_sequences_train, n_human_sequences_train, n_sequences_test, n_sequences_final_performance, d_model, n_layers, n_head, sim_lr, human_lr, batch_size, dropout, run_idx, on_cluster, test_batch_increment_sim, test_batch_increment_human, save_folder_name, fix_unit, save_file_name)
#      80     print("Loading Data")
# ---> 81     train_data_sim, val_data_sim, test_data_sim, train_data_human, val_data_human, test_data_human = load_data(sim_data_path, human_data_path,this_seed=run_idx,split_human_data=True)
#      82
#
# ~/projects/RNNs/load_data_funs.py in load_data(sim_data_path, human_data_path, split_human_data, this_seed)
#      22
# ---> 23     a = [json.load(open(train_files[i])) for i in range(15)]
#      24     train_trials = [item for sublist in a for item in sublist]
#
# ~/projects/RNNs/load_data_funs.py in <listcomp>(.0)
#      22
# ---> 23     a = [json.load(open(train_files[i])) for i in range(15)]
#      24     train_trials = [item for sublist in a for item in sublist]
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#
# ~/.conda/envs/pDL/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~/.conda/envs/pDL/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
len(job_runs)
# Out:
# 100
