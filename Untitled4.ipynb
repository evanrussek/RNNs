# %%
# %run Train_at_Best_Params_Control.py
# Out:
# 9
# {'model_name': 'MLP', 'train_seq_part': 'fix_only', 'n_simulation_sequences_train': 147232, 'n_human_sequences_train': 0, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 32, 'n_layers': 2, 'n_head': 2, 'sim_lr': 0.001, 'human_lr': 0, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 0, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Control_Best_Param_Results', 'save_file_name': 'Simulated_Only_Pred_Human_prop_run_0', 'fix_unit': 'prop'}
# <class 'numpy.int64'>
# Loading Data
# cpu
# Training the model
# Training on simulated data
# number of simulation seqeuences: 6432number of human seqeuences: 0 sim test loss: 6.6853465139865875 human test loss 8.85633385181427
# number of simulation seqeuences: 12832number of human seqeuences: 0 sim test loss: 4.8259406089782715 human test loss 5.673263281583786
# ...

# %%
# %run Train_at_Best_Params_Sequential.py
# Out:
# 9
# {'model_name': 'GRU', 'train_seq_part': 'fix_and_choice', 'n_simulation_sequences_train': 364832, 'n_human_sequences_train': 25600, 'n_sequences_test': 500, 'n_sequences_final_performance': 500, 'd_model': 32, 'n_layers': 0, 'n_head': 0, 'sim_lr': 0.001, 'human_lr': 0.001, 'batch_size': 32, 'dropout': 0.1, 'run_idx': 0, 'on_cluster': True, 'test_batch_increment_sim': 200, 'test_batch_increment_human': 200, 'save_folder_name': 'Sequential_Best_Param_Results', 'save_file_name': 'fix_and_choice_Simulated_and_Human_GRU_all_run_0', 'fix_unit': 'ID'}
# <class 'numpy.int64'>
# Loading Data
# cpu
# Training the model
# Training on simulated data
# number of simulation seqeuences: 6432number of human seqeuences: 0 sim test loss: 4.90056899189949 human test loss 5.71010684967041
# number of simulation seqeuences: 12832number of human seqeuences: 0 sim test loss: 4.860843390226364 human test loss 5.745718091726303
# ...

# %%
len(job_runs)
# Out:
# 600
