# %%
# %run train_sim_and_human_test_human.py
# Out:
# Training on simulated data
# batch num100 sim test loss: 7.2071109125691075 human test loss 7.464729432136782
# batch num200 sim test loss: 5.699908287294449 human test loss 5.710480936111942
# batch num300 sim test loss: 5.216039842174899 human test loss 5.217026556691816
# batch num400 sim test loss: 4.924371950088009 human test loss 4.952609108340356
# batch num500 sim test loss: 4.843872439476751 human test loss 4.869760128759569
# batch num600 sim test loss: 4.809810992210142 human test loss 4.85951861258476
# batch num700 sim test loss: 4.800362640811551 human test loss 4.854151818060106
# batch num800 sim test loss: 4.813709159051219 human test loss 4.847375569805022
# batch num900 sim test loss: 4.8356533588901645 human test loss 4.855859948742774
# batch num1000 sim test loss: 4.806826753001059 human test loss 4.843114053049395
# batch num1100 sim test loss: 4.811668242177656 human test loss 4.843248744164744
# ...

# %%
prop_pretrain = np.linspace(0,1,5);

# %%
prop_pretrain
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])
